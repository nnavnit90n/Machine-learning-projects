# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
a=cv2.imread("E:\\navneet personl\\SHAREit\\Redmi 4A\\photo\\index.png")

# %%
print(a.shape)
# Out:
# (184, 274, 3)

# %%
plt.imshow(a)

# %%
img=cv2.cvtColor(a,cv2.COLOR_BGR2GRAY)
print(img.shape)
plt.imshow(img)
# Out:
# (184, 274)

# %%
img2=img.reshape(1,1,184,274)

# %%
print(img2.shape)
# Out:
# (1, 1, 184, 274)

# %%
from keras import backend

# %%
backend.set_image_data_format("channels_first")

# %%
import tensorflow as tf

# %%
model=Sequential()
model.add(Convolution2D(28, kernel_size=(3,3), input_shape=(1,900,900)))
model.add(Activation('relu'))
model.add(Convolution2D(28, kernel_size=(3,3), input_shape=(1,900,900)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_Size=(2,2)))
model.add(Convolution2D(28, kernel_size=(3,3), input_shape=(1,900,900)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_Size=(2,2)))
#input_shape=(1,900,900)
#model = Sequential()
#model.add(Conv2D(28, kernel_size=(3,3), input_shape=input_shape))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Flatten()) # Flattening the 2D arrays for fully connected layers
#model.add(Dense(128, activation=tf.nn.relu))
#model.add(Dropout(0.2))
#model.add(Dense(10,activation=tf.nn.softmax))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-14794a9ff391> in <module>
#       1 model=Sequential()
# ----> 2 model.add(Convolution2D(28, kernel_size=(3,3), input_shape=(1,900,900)))
#       3 model.add(Activation('relu'))
#       4 model.add(Convolution2D(28, kernel_size=(3,3), input_shape=(1,900,900)))
#       5 model.add(Activation('relu'))
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\sequential.py in add(self, layer)
#     164                     # and create the node connecting the current layer
#     165                     # to the input layer we just created.
# --> 166                     layer(x)
#     167                     set_inputs = True
#     168             else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in symbolic_fn_wrapper(*args, **kwargs)
# ...

# %%
tf.config.experimental.list_physical_devices('GPU')
# Out:
# []
