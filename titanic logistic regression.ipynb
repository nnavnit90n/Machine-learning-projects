# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
titanic=pd.read_csv('C:\\Users\\Admin\\Desktop\\Skill Circle\\dataset\\titanic1.csv')
titanic
# Out:
#     PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked  \
# 0                                      1\t0\t3\tBraund
# 1                                     2\t1\t1\tCumings
# 2                                   3\t1\t3\tHeikkinen
# 3                                    4\t1\t1\tFutrelle
# 4                                       5\t0\t3\tAllen
# ..                                                 ...
# 151                                   152\t1\t1\tPears
# 152                                     153\t0\t3\tMeo
# 153                            154\t0\t3\tvan Billiard
# 154                                   155\t0\t3\tOlsen
# 155                                156\t0\t1\tWilliams
#
#                                                      x
# 0     Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 1     Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 2     Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# ...

# %%
print(titanic.columns)
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
titanic=titanic['x'].str.split('\t',n=10,expand=True)
titanic.head()
# Out:
#                                              0       1   2  3  4  \
# 0                              Mr. Owen Harris    male  22  1  0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38  1  0
# 2                                  Miss. Laina  female  26  0  0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35  1  0
# 4                            Mr. William Henry    male  35  0  0
#
#                   5        6     7  8
# 0         A/5 21171     7.25        S
# 1          PC 17599  71.2833   C85  C
# 2  STON/O2. 3101282    7.925        S
# 3            113803     53.1  C123  S
# 4            373450     8.05        S

# %%
d=pd.DataFrame(titanic)
d
# Out:
#                                                0       1     2  3  4  \
# 0                                Mr. Owen Harris    male    22  1  0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female    38  1  0
# 2                                    Miss. Laina  female    26  0  0
# 3             Mrs. Jacques Heath (Lily May Peel)  female    35  1  0
# 4                              Mr. William Henry    male    35  0  0
# ..                                           ...     ...   ... .. ..
# 151                   Mrs. Thomas (Edith Wearne)  female    22  1  0
# 152                                  Mr. Alfonzo    male  55.5  0  0
# 153                            Mr. Austin Blyler    male  40.5  0  2
# 154                               Mr. Ole Martin    male        0  0
# 155                            Mr. Charles Duane    male    51  0  1
#
#                     5        6     7  8
# 0           A/5 21171     7.25        S
# 1            PC 17599  71.2833   C85  C
# ...

# %%
df = titanic.rename(columns ={'0':'Name','1': 'Sex','2': 'age','3': 'SibSp','4':'Parch'})
df
# Out:
#                                                0       1     2  3  4  \
# 0                                Mr. Owen Harris    male    22  1  0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female    38  1  0
# 2                                    Miss. Laina  female    26  0  0
# 3             Mrs. Jacques Heath (Lily May Peel)  female    35  1  0
# 4                              Mr. William Henry    male    35  0  0
# ..                                           ...     ...   ... .. ..
# 151                   Mrs. Thomas (Edith Wearne)  female    22  1  0
# 152                                  Mr. Alfonzo    male  55.5  0  0
# 153                            Mr. Austin Blyler    male  40.5  0  2
# 154                               Mr. Ole Martin    male        0  0
# 155                            Mr. Charles Duane    male    51  0  1
#
#                     5        6     7  8
# 0           A/5 21171     7.25        S
# 1            PC 17599  71.2833   C85  C
# ...

# %%
titanic1['Name']=titanic1[0]
titanic1.head()
# Out:
#                                              0       1   2  3  4  \
# 0                              Mr. Owen Harris    male  22  1  0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38  1  0
# 2                                  Miss. Laina  female  26  0  0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35  1  0
# 4                            Mr. William Henry    male  35  0  0
#
#                   5        6     7  8  \
# 0         A/5 21171     7.25        S
# 1          PC 17599  71.2833   C85  C
# 2  STON/O2. 3101282    7.925        S
# 3            113803     53.1  C123  S
# 4            373450     8.05        S
#
#                                           Name  \
# 0                              Mr. Owen Harris
# 1   Mrs. John Bradley (Florence Briggs Thayer)
# 2                                  Miss. Laina
# 3           Mrs. Jacques Heath (Lily May Peel)
# 4                            Mr. William Henry
#
#                                         Gender
# ...

# %%
d=pd.DataFrame(titanic)

# %%
titanic1['y']=titanic1[1]
titanic1
# Out:
#                                                0       1     2  3  4  \
# 0                                Mr. Owen Harris    male    22  1  0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female    38  1  0
# 2                                    Miss. Laina  female    26  0  0
# 3             Mrs. Jacques Heath (Lily May Peel)  female    35  1  0
# 4                              Mr. William Henry    male    35  0  0
# ..                                           ...     ...   ... .. ..
# 151                   Mrs. Thomas (Edith Wearne)  female    22  1  0
# 152                                  Mr. Alfonzo    male  55.5  0  0
# 153                            Mr. Austin Blyler    male  40.5  0  2
# 154                               Mr. Ole Martin    male        0  0
# 155                            Mr. Charles Duane    male    51  0  1
#
#                     5        6     7  8  \
# 0           A/5 21171     7.25        S
# 1            PC 17599  71.2833   C85  C
# ...

# %%
titanic['Name']=titanic1[0]
titanic['Gender']=titanic1[1]
titanic.head()
# Out:
#   PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked  \
# 0                                    1\t0\t3\tBraund
# 1                                   2\t1\t1\tCumings
# 2                                 3\t1\t3\tHeikkinen
# 3                                  4\t1\t1\tFutrelle
# 4                                     5\t0\t3\tAllen
#
#                                                    x  \
# 0   Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 1   Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 2   Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 3   Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 4   Mr. William Henry\tmale\t35\t0\t0\t373450\t8....
#
#                                           Name  Gender
# 0                              Mr. Owen Harris    male
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female
# 2                                  Miss. Laina  female
# 3           Mrs. Jacques Heath (Lily May Peel)  female
# ...

# %%
titanic.drop(columns=['x'],axis=1,inplace=True)
titanic.head()
# Out:
#   PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked  \
# 0                                    1\t0\t3\tBraund
# 1                                   2\t1\t1\tCumings
# 2                                 3\t1\t3\tHeikkinen
# 3                                  4\t1\t1\tFutrelle
# 4                                     5\t0\t3\tAllen
#
#                                           Name  Gender
# 0                              Mr. Owen Harris    male
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female
# 2                                  Miss. Laina  female
# 3           Mrs. Jacques Heath (Lily May Peel)  female
# 4                            Mr. William Henry    male

# %%
titanic1.drop(columns=['y'],axis=1,inplace=True)
titanic1.head()
# Out:
#                                              0       1   2  3  4  \
# 0                              Mr. Owen Harris    male  22  1  0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38  1  0
# 2                                  Miss. Laina  female  26  0  0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35  1  0
# 4                            Mr. William Henry    male  35  0  0
#
#                   5        6     7  8  \
# 0         A/5 21171     7.25        S
# 1          PC 17599  71.2833   C85  C
# 2  STON/O2. 3101282    7.925        S
# 3            113803     53.1  C123  S
# 4            373450     8.05        S
#
#                                           Name  \
# 0                              Mr. Owen Harris
# 1   Mrs. John Bradley (Florence Briggs Thayer)
# 2                                  Miss. Laina
# 3           Mrs. Jacques Heath (Lily May Peel)
# 4                            Mr. William Henry
#
#                                         Gender
# ...

# %%
titanic1['Gender']=titanic1[0]
titanic1.head()
# Out:
#                                              0       1   2  3  4  \
# 0                              Mr. Owen Harris    male  22  1  0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38  1  0
# 2                                  Miss. Laina  female  26  0  0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35  1  0
# 4                            Mr. William Henry    male  35  0  0
#
#                   5        6     7  8  \
# 0         A/5 21171     7.25        S
# 1          PC 17599  71.2833   C85  C
# 2  STON/O2. 3101282    7.925        S
# 3            113803     53.1  C123  S
# 4            373450     8.05        S
#
#                                           Name       y  \
# 0                              Mr. Owen Harris    male
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female
# 2                                  Miss. Laina  female
# 3           Mrs. Jacques Heath (Lily May Peel)  female
# 4                            Mr. William Henry    male
#
# ...
